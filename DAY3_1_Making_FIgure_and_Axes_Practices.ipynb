# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize = (10,10))
ax1 = plt.subplot2grid((3,1),(0,0),fig = fig)
ax2 = plt.subplot2grid((3,1),(1,0),fig = fig)
ax3 = plt.subplot2grid((3,1),(2,0),fig = fig)

# %%
fig = plt.figure(figsize = (10,10))
ax1 = fig.add_subplot(3,1,1)
ax2 = fig.add_subplot(3,1,2)
ax3 = fig.add_subplot(3,1,3)

# %%
fig,axes = plt.subplots(3,1,figsize=(10,10))

# %%
fig2 = plt.figure()
ax1 = fig2.add_subplot(2,2,1)
ax2 = fig2.add_subplot(2,2,2)
ax3 = fig2.add_subplot(2,2,3)
ax4 = fig2.add_subplot(2,2,4)

# %%
fig,axes = plt.subplots(2,2,figsize=(10,10))

# %%
fig2 = plt.figure()
ax1 = plt.subplot2grid((2,2),(0,0),fig = fig2)
ax2 = plt.subplot2grid((2,2),(0,1),fig = fig2)
ax3 = plt.subplot2grid((2,2),(1,0),fig = fig2)
ax4 = plt.subplot2grid((2,2),(1,1),fig = fig2)

# %%
fig3 = plt.figure()
ax1 = plt.subplot2grid((2,2),(0,0),rowspan = 2,fig = fig3)
ax2 = plt.subplot2grid((2,2),(0,1),fig = fig3)
ax3 = plt.subplot2grid((2,2),(1,1),fig = fig3)

# %%
fig3 = plt.figure()
ax1 = fig3.add_subplot(1,2,1)
ax2 = fig3.add_subplot(2,2,2)
ax3 = fig3.add_subplot(2,2,4)

# %%
fig4 = plt.figure(figsize = (10,10))
ax1 = plt.subplot2grid((5,4),
                       (0,0),
                       rowspan = 2,
                       colspan = 2,
                       fig = fig4)

ax2 = plt.subplot2grid((5,4),
                       (0,2),
                       rowspan = 2,
                       colspan = 2,
                       fig = fig4)

ax3 = plt.subplot2grid((5,4),
                       (2,0),
                       fig = fig4)

ax4 = plt.subplot2grid((5,4),
                       (2,1),
                       fig = fig4)

ax5 = plt.subplot2grid((5,4),
                       (2,2),
                       fig = fig4)

ax6 = plt.subplot2grid((5,4),
                       (2,3),
                       fig = fig4)

ax7 = plt.subplot2grid((5,4),
                       (3,0),
                       fig = fig4)


ax8 = plt.subplot2grid((5,4),
                       (3,1),
                       fig = fig4)


ax9 = plt.subplot2grid((5,4),
                       (3,2),
                       fig = fig4)


ax10 = plt.subplot2grid((5,4),
                       (3,3),
                       fig = fig4)

# %%
fig = plt.figure(figsize = (20,20))
axes = np.empty(shape = (0,))
axes = np.append(axes ,plt.subplot2grid((5,4),(0,0),rowspan = 2, colspan = 2))
axes = np.append(axes ,plt.subplot2grid((5,4),(0,2),rowspan = 2, colspan = 2))

for r_idx in range(2,5):
    for c_idx in range(4):
        np.append(axes,plt.subplot2grid((5,4),(r_idx,c_idx)))
