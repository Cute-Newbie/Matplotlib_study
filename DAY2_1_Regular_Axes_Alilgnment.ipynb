# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Making FIg and Axes Simultaneously

fig,axes = plt.subplots(nrows = 2,ncols = 1)
axes[0]
axes[1]
# Out:
# <Axes: >

# %%
# We can check the outcome is the same
fig1 = plt.figure()
ax1 = fig1.add_subplot(2,1,1)
ax2 = fig1.add_subplot(2,1,2)

# %%
#Unpacking
fig3,(ax1,ax2) = plt.subplots(nrows = 2,ncols = 1,figsize = (7,7))

# %%
fig,axes = plt.subplots(nrows = 2,
                        ncols = 2,
                        figsize = (7,7))

print(axes.shape)
# Out:
# (2, 2)

# %%
for ax in axes.flat:
    print(ax)
# Out:
# Axes(0.125,0.53;0.352273x0.35)
# Axes(0.547727,0.53;0.352273x0.35)
# Axes(0.125,0.11;0.352273x0.35)
# Axes(0.547727,0.11;0.352273x0.35)

# %%
title_list = ['Training_image','2 scales','4 scales','5 scales','6 scales','8 scales ']
fig,axes = plt.subplots(nrows = 2, ncols = 3, figsize = (20,10))

for idx,ax in enumerate(axes.flat):
    ax.set_title(title_list[idx],fontsize = 20)
